# %% [markdown]
# # Task
#
# Verify station weather with scripts.
#
# # Context
#
# Use station 570's t2m (temperature) in 2023-01-01 0:00 for verification.
#
# 5 source files:
#
# - Changmin's GRIB
# - Changmin's NetCDF
# - Tiger's NetCDF
# - Tara's GRIB download 1, range 1
# - Tara's GRIB download 2, range 2

# %%
# read grib file(in nc format) using pygrib
! pip install pygrib
import pygrib
# Out:
# ...
#   Obtaining dependency information for pygrib from https://files.pythonhosted.org/packages/50/5d/12ae450349ce3d51844e775dff0ee1b04a9aee963d6ed6102ced290805b4/pygrib-2.1.6-cp311-cp311-macosx_11_0_x86_64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 14.4 MB/s eta 0:00:0000:0100:01
# ...

# %%
def read_grib_file(file_path):
	grbs = pygrib.open(file_path)
	for grb in grbs:
		print(grb)
	grbs.close()

read_grib_file('/Users/rainylty/STUDY/fall24/1-GRA/Resilient_energy_network/1-data/Changmin-NetCDF-2023-01-t2m.grib')
# Out:
# 1:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 202212310000
# 2:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 202212310000
# 3:2 metre dewpoint temperature:K (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 202212310000
# 4:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 202212310000
# 5:Runoff:m (accum):regular_ll:surface:level 0:fcst time 23-24 hrs (accum):from 202212310000
# 6:Skin temperature:K (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 202301010000
# 7:Snow cover:% (instant):regular_ll:surface:level 0 -:fcst time 24 hrs:from 202212310000
# 8:Snow density:kg m**-3 (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 202301010000
# 9:Snow depth:m (instant):regular_ll:surface:level 0 -:fcst time 24 hrs:from 202212310000
# ...

# %%
# return the girb file cordinate range

# return the t2m value in grib at station 570, 2023-01-01 0:00
