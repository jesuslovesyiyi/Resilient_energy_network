# %% [markdown]
# ## Use Case
#
# This notebook reads downloaded GRIB files and join weather attributes by location to each station, assigning grid data (df) to stations from station_df based on the nearest grid point.
#
# Main function: assign_nearest_grid_values(df, station_df, grid_points, nearest_grid_idx)
#
# Method: scipy.spatial.KDTree for nearest neighbor searches

# %%
year=2013

# %%
import pandas as pd
import pygrib
import os
import numpy as np
import cfgrib 
import xarray as xr
from scipy.spatial import KDTree

# %% [markdown]
# ## Main Function

# %%
def build_kdtree(df):
    """
    Build a KDTree from the gridded dataset.
    
    Args:
        df (pd.DataFrame): DataFrame containing the grib data with lat and lon as the index.

    Returns:
        KDTree: A KDTree built on lat/lon coordinates.
        np.array: Grid points as an array of lat/lon pairs.
    """
    # Ensure lat/lon values are floats and create an array of lat/lon pairs
    grid_points = np.array(list(zip(df.index.get_level_values('latitude').astype(float), df.index.get_level_values('longitude').astype(float))))
    
    # Build and return the KDTree
    return KDTree(grid_points), grid_points

# %%
def find_nearest_grid_points(tree, station_df):
    """
    Find the nearest grid points for each station using the KDTree.
    
    Args:
        tree (KDTree): The KDTree built from grid points.
        station_df (pd.DataFrame): DataFrame containing station coordinates with 'station_lat' and 'station_lon' columns.

    Returns:
        np.array: Nearest grid points for each station in station_df.
    """
    # Extract station coordinates as numpy array
    station_coords = station_df[['Lat', 'Lon']].to_numpy()
    
    # Query the KDTree for nearest grid points
    _, nearest_grid_idx = tree.query(station_coords)
    
    return nearest_grid_idx

# %%
def assign_nearest_grid_values(df, station_df, grid_points, nearest_grid_idx):
    """
    Assign the nearest grid data (t2m, wind_u, wind_v) to each station in station_df.
    
    Args:
        df (pd.DataFrame): The grib data with lat/lon index and variables like t2m, wind_u, wind_v.
        station_df (pd.DataFrame): DataFrame containing station coordinates.
        grid_points (np.array): Grid points from the KDTree.
        nearest_grid_idx (np.array): Indices of the nearest grid points for each station.

    Returns:
        pd.DataFrame: station_df with grid data (t2m, wind_u, wind_v) appended.
    """
    # Get the nearest grid points as lat/lon tuples
    nearest_grid_points = [(round(lat, 3), round(lon, 3)) for lat, lon in grid_points[nearest_grid_idx]]
    
    # Ensure the index of df is also rounded and in tuple form
    df.index = pd.MultiIndex.from_tuples(
        [(round(lat, 3), round(lon, 3)) for lat, lon in df.index], 
        names=['lat', 'lon']
    )
    
    # Extract the grid data for the nearest points
    nearest_grid_values = df.loc[nearest_grid_points].reset_index()
    
    # Join the nearest grid values with the station data
    station_df = pd.concat([station_df.reset_index(drop=True), nearest_grid_values[['t2m', 'u10', 'v10','tp']]], axis=1)
    
    return station_df

# %%
def read_grib_file(file_path):
	grbs = pygrib.open(file_path)
	for grb in grbs:
		print(grb)
	grbs.close()
	
	return grbs

# %%
input_dir = f'{year}'
station_file='STATION.csv'
station_df = pd.read_csv(station_file)
output_dir = f'station_by_datetime_csv/{year}'

for file in os.listdir(input_dir):
    if file.endswith('.grib'):
        print(file)
        grbs = read_grib_file(os.path.join(input_dir, file))
        
        with xr.open_dataset(os.path.join(input_dir, file)) as ds:
            df_raw = ds.to_dataframe()
            df = df_raw.drop(columns=['number', 'time', 'step', 'surface', 'valid_time'])
            # get date and time
            date = file.split('_')[2]
            time = file.split('_')[3].split('.')[0]
            
            df['date'] = date
            df['time'] = time
            # build KDTree
            tree, grid_points = build_kdtree(df)

            station_coords = station_df[['Lat', 'Lon']].to_numpy()

            _, nearest_grid_idx = tree.query(station_coords)

            nearest_grid_points = grid_points[nearest_grid_idx]
            
            nearest_grid_points = [(round(lat, 3), round(lon, 3)) for lat, lon in nearest_grid_points]

            df.index = pd.MultiIndex.from_tuples([(round(lat, 3), round(lon, 3)) for lat, lon in df.index], names=['lat', 'lon'])

            nearest_grid_values = df.loc[nearest_grid_points].reset_index()

            station_df_final = pd.concat([station_df.reset_index(drop=True), nearest_grid_values[['t2m', 'u10', 'v10','tp','date','time']]], axis=1)

            station_df_final.to_csv(f'{output_dir}/{date}_{time}_station.csv')
# Out:
# era5_land_20130802_2100.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201308020000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201308020000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201308020000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 20-21 hrs (accum):from 201308020000
# era5_land_20130706_1200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201307060000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201307060000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201307060000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 11-12 hrs (accum):from 201307060000
# era5_land_20131229_2300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201312290000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201312290000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201312290000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 22-23 hrs (accum):from 201312290000
# era5_land_20131119_1800.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201311190000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201311190000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201311190000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 17-18 hrs (accum):from 201311190000
# era5_land_20130730_1900.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201307300000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201307300000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201307300000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 18-19 hrs (accum):from 201307300000
# era5_land_20131106_2000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201311060000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201311060000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201311060000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 19-20 hrs (accum):from 201311060000
# era5_land_20130830_0100.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201308300000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201308300000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201308300000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201308300000
# era5_land_20130929_0200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201309290000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201309290000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201309290000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201309290000
# era5_land_20131025_0600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201310250000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201310250000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201310250000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201310250000
# era5_land_20131127_1600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201311270000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201311270000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201311270000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 15-16 hrs (accum):from 201311270000
# era5_land_20130617_1400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201306170000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201306170000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201306170000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201306170000
# era5_land_20130715_0400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201307150000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201307150000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201307150000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201307150000
# era5_land_20130823_1700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201308230000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201308230000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201308230000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 16-17 hrs (accum):from 201308230000
# era5_land_20130921_0700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201309210000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201309210000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201309210000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201309210000
# era5_land_20131208_1500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201312080000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201312080000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201312080000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201312080000
# era5_land_20131213_0600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201312130000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201312130000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201312130000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201312130000
# era5_land_20130626_0500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201306260000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201306260000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201306260000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 4-5 hrs (accum):from 201306260000
# era5_land_20130724_1500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201307240000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201307240000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201307240000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201307240000
# era5_land_20131014_1700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201310140000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201310140000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201310140000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 16-17 hrs (accum):from 201310140000
# era5_land_20131116_0700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201311160000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201311160000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201311160000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201311160000
# era5_land_20130809_1500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201308090000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201308090000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201308090000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201308090000
# era5_land_20130812_0600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201308120000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201308120000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201308120000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201308120000
# era5_land_20130910_1600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201309100000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201309100000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201309100000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 15-16 hrs (accum):from 201309100000
# era5_land_20131222_1700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201312220000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201312220000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201312220000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 16-17 hrs (accum):from 201312220000
# era5_land_20131007_0100.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201310070000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201310070000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201310070000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201310070000
# era5_land_20131105_1100.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201311050000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201311050000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201311050000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 10-11 hrs (accum):from 201311050000
# era5_land_20130701_0800.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201307010000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201307010000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201307010000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 7-8 hrs (accum):from 201307010000
# era5_land_20130828_2300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201308280000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201308280000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201308280000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 22-23 hrs (accum):from 201308280000
# era5_land_20131203_2100.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201312030000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201312030000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201312030000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 20-21 hrs (accum):from 201312030000
# era5_land_20131128_0900.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201311280000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201311280000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201311280000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 8-9 hrs (accum):from 201311280000
# era5_land_20130801_1000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201308010000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201308010000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201308010000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 9-10 hrs (accum):from 201308010000
# era5_land_20130705_2300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201307050000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201307050000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201307050000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 22-23 hrs (accum):from 201307050000
# era5_land_20130903_0000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201309020000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201309020000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201309020000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 23-24 hrs (accum):from 201309020000
# era5_land_20131231_0100.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201312310000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201312310000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201312310000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201312310000
# era5_land_20130918_1300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201309180000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201309180000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201309180000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201309180000
# era5_land_20131013_1300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201310130000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201310130000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201310130000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201310130000
# era5_land_20131008_0000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201310070000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201310070000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201310070000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 23-24 hrs (accum):from 201310070000
# era5_land_20131111_0300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201311110000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201311110000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201311110000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 2-3 hrs (accum):from 201311110000
# era5_land_20130621_0100.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201306210000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201306210000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201306210000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201306210000
# era5_land_20131025_1800.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201310250000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201310250000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201310250000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 17-18 hrs (accum):from 201310250000
# era5_land_20130827_2200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201308270000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201308270000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201308270000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 21-22 hrs (accum):from 201308270000
# era5_land_20130723_1100.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201307230000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201307230000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201307230000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 10-11 hrs (accum):from 201307230000
# era5_land_20131127_0800.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201311270000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201311270000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201311270000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 7-8 hrs (accum):from 201311270000
# era5_land_20130815_0200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201308150000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201308150000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201308150000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201308150000
# era5_land_20131225_1300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201312250000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201312250000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201312250000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201312250000
# era5_land_20130917_1200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201309170000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201309170000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201309170000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 11-12 hrs (accum):from 201309170000
# era5_land_20130823_0900.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201308230000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201308230000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201308230000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 8-9 hrs (accum):from 201308230000
# era5_land_20131213_1800.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201312130000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201312130000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201312130000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 17-18 hrs (accum):from 201312130000
# era5_land_20131123_2300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201311230000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201311230000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201311230000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 22-23 hrs (accum):from 201311230000
# era5_land_20130921_1900.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201309210000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201309210000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201309210000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 18-19 hrs (accum):from 201309210000
# era5_land_20130629_0400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201306290000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201306290000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201306290000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201306290000
# era5_land_20130730_0700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201307300000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201307300000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201307300000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201307300000
# era5_land_20131119_0600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201311190000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201311190000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201311190000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201311190000
# era5_land_20131102_1500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201311020000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201311020000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201311020000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201311020000
# era5_land_20130806_1400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201308060000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201308060000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201308060000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201308060000
# era5_land_20130904_0400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201309040000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201309040000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201309040000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201309040000
# era5_land_20131031_1400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201310310000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201310310000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201310310000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201310310000
# era5_land_20131128_1700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201311280000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201311280000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201311280000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 16-17 hrs (accum):from 201311280000
# era5_land_20130618_1500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201306180000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201306180000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201306180000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201306180000
# era5_land_20130701_1600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201307010000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201307010000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201307010000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 15-16 hrs (accum):from 201307010000
# era5_land_20131207_1400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201312070000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201312070000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201312070000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201312070000
# era5_land_20131014_0900.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201310140000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201310140000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201310140000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 8-9 hrs (accum):from 201310140000
# era5_land_20130709_1300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201307090000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201307090000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201307090000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201307090000
# era5_land_20131226_2200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201312260000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201312260000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201312260000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 21-22 hrs (accum):from 201312260000
# era5_land_20130712_0000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201307110000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201307110000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201307110000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 23-24 hrs (accum):from 201307110000
# era5_land_20131116_1900.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201311160000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201311160000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201311160000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 18-19 hrs (accum):from 201311160000
# era5_land_20130914_2300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201309140000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201309140000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201309140000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 22-23 hrs (accum):from 201309140000
# era5_land_20131022_0200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201310220000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201310220000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201310220000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201310220000
# era5_land_20131120_1200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201311200000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201311200000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201311200000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 11-12 hrs (accum):from 201311200000
# era5_land_20131010_2200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201310100000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201310100000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201310100000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 21-22 hrs (accum):from 201310100000
# era5_land_20130812_1800.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201308120000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201308120000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201308120000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 17-18 hrs (accum):from 201308120000
# era5_land_20131109_2100.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201311090000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201311090000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201311090000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 20-21 hrs (accum):from 201311090000
# era5_land_20131222_0900.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201312220000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201312220000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201312220000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 8-9 hrs (accum):from 201312220000
# era5_land_20130910_0800.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201309100000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201309100000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201309100000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 7-8 hrs (accum):from 201309100000
# era5_land_20130824_1300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201308240000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201308240000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201308240000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201308240000
# era5_land_20131214_0200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201312140000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201312140000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201312140000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201312140000
# era5_land_20130720_2000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201307200000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201307200000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201307200000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 19-20 hrs (accum):from 201307200000
# era5_land_20130926_0300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201309260000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201309260000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201309260000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 2-3 hrs (accum):from 201309260000
# era5_land_20130830_1300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201308300000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201308300000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201308300000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201308300000
# era5_land_20130929_1000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201309290000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201309290000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201309290000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 9-10 hrs (accum):from 201309290000
# era5_land_20131004_2200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201310040000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201310040000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201310040000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 21-22 hrs (accum):from 201310040000
# era5_land_20130806_1800.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201308060000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201308060000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201308060000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 17-18 hrs (accum):from 201308060000
# era5_land_20130904_0800.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201309040000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201309040000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201309040000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 7-8 hrs (accum):from 201309040000
# era5_land_20130629_0800.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201306290000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201306290000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201306290000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 7-8 hrs (accum):from 201306290000
# era5_land_20130819_2000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201308190000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201308190000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201308190000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 19-20 hrs (accum):from 201308190000
# era5_land_20130706_0000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201307050000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201307050000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201307050000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 23-24 hrs (accum):from 201307050000
# era5_land_20131102_1900.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201311020000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201311020000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201311020000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 18-19 hrs (accum):from 201311020000
# era5_land_20130823_0500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201308230000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201308230000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201308230000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 4-5 hrs (accum):from 201308230000
# era5_land_20130921_1500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201309210000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201309210000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201309210000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201309210000
# era5_land_20131208_0700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201312080000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201312080000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201312080000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201312080000
# era5_land_20131213_1400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201312130000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201312130000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201312130000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201312130000
# era5_land_20130617_0600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201306170000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201306170000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201306170000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201306170000
# era5_land_20130715_1600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201307150000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201307150000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201307150000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 15-16 hrs (accum):from 201307150000
# era5_land_20131025_1400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201310250000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201310250000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201310250000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201310250000
# era5_land_20131127_0400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201311270000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201311270000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201311270000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201311270000
# era5_land_20130809_0700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201308090000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201308090000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201308090000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201308090000
# era5_land_20130812_1400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201308120000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201308120000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201308120000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201308120000
# era5_land_20130910_0400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201309100000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201309100000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201309100000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201309100000
# era5_land_20131222_0500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201312220000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201312220000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201312220000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 4-5 hrs (accum):from 201312220000
# era5_land_20131014_0500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201310140000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201310140000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201310140000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 4-5 hrs (accum):from 201310140000
# era5_land_20131116_1500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201311160000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201311160000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201311160000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201311160000
# era5_land_20130626_1700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201306260000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201306260000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201306260000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 16-17 hrs (accum):from 201306260000
# era5_land_20130724_0700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201307240000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201307240000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201307240000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201307240000
# era5_land_20131207_1800.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201312070000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201312070000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201312070000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 17-18 hrs (accum):from 201312070000
# era5_land_20130801_0200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201308010000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201308010000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201308010000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201308010000
# era5_land_20130903_1200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201309030000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201309030000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201309030000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 11-12 hrs (accum):from 201309030000
# era5_land_20131231_1300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201312310000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201312310000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201312310000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201312310000
# era5_land_20130918_0100.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201309180000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201309180000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201309180000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201309180000
# era5_land_20131031_1800.grib
# ...
# era5_land_20130805_0400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201308050000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201308050000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201308050000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201308050000
# era5_land_20130728_0400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201307280000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201307280000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201307280000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201307280000
# era5_land_20131101_0500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201311010000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201311010000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201311010000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 4-5 hrs (accum):from 201311010000
# era5_land_20131018_0600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201310180000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201310180000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201310180000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201310180000
# era5_land_20131003_1500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201310030000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201310030000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201310030000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201310030000
# era5_land_20131221_0700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201312210000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201312210000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201312210000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201312210000
# era5_land_20130908_1500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201309080000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201309080000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201309080000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201309080000
# era5_land_20130913_0600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201309130000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201309130000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201309130000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201309130000
# era5_land_20130811_1600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201308110000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201308110000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201308110000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 15-16 hrs (accum):from 201308110000
# era5_land_20130727_0500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201307270000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201307270000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201307270000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 4-5 hrs (accum):from 201307270000
# era5_land_20130625_1500.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201306250000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201306250000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201306250000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201306250000
# era5_land_20131115_1700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201311150000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201311150000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201311150000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 16-17 hrs (accum):from 201311150000
# era5_land_20131017_0700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201310170000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201310170000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201310170000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201310170000
# era5_land_20131229_0200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201312290000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201312290000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201312290000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201312290000
# era5_land_20130802_0000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201308010000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201308010000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201308010000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 23-24 hrs (accum):from 201308010000
# era5_land_20130819_1300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201308190000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201308190000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201308190000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201308190000
# era5_land_20130702_1800.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201307020000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201307020000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201307020000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 17-18 hrs (accum):from 201307020000
# era5_land_20131106_0100.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201311060000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201311060000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201311060000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201311060000
# era5_land_20131004_1100.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201310040000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201310040000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201310040000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 10-11 hrs (accum):from 201310040000
# era5_land_20130929_2300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201309290000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201309290000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201309290000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 22-23 hrs (accum):from 201309290000
# era5_land_20130830_2000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201308300000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201308300000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201308300000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 19-20 hrs (accum):from 201308300000
# era5_land_20131029_0900.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201310290000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201310290000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201310290000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 8-9 hrs (accum):from 201310290000
# era5_land_20131007_2000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201310070000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201310070000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201310070000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 19-20 hrs (accum):from 201310070000
# era5_land_20131203_0000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201312020000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201312020000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201312020000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 23-24 hrs (accum):from 201312020000
# era5_land_20131218_1300.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201312180000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201312180000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201312180000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201312180000
# era5_land_20130828_0200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201308280000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201308280000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201308280000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201308280000
# era5_land_20131231_2000.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201312310000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201312310000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201312310000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 19-20 hrs (accum):from 201312310000
# era5_land_20130903_2100.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201309030000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201309030000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201309030000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 20-21 hrs (accum):from 201309030000
# era5_land_20130705_0200.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201307050000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201307050000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201307050000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201307050000
# era5_land_20131018_1800.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201310180000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201310180000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201310180000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 17-18 hrs (accum):from 201310180000
# era5_land_20131210_1600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201312100000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201312100000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201312100000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 15-16 hrs (accum):from 201312100000
# era5_land_20130922_1700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201309220000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201309220000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201309220000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 16-17 hrs (accum):from 201309220000
# era5_land_20130820_0700.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201308200000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201308200000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201308200000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201308200000
# era5_land_20131124_0600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201311240000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201311240000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201311240000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201311240000
# era5_land_20131026_1600.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201310260000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201310260000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201310260000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 15-16 hrs (accum):from 201310260000
# era5_land_20130716_1400.grib
# 1:2 metre temperature:K (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201307160000
# 2:10 metre U wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201307160000
# 3:10 metre V wind component:m s**-1 (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201307160000
# 4:Total precipitation:m (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201307160000

# %%
station_df[station_df['station_id'] == 489]
# Out:
#      station_id Location name  ESMI_ID        From date          To date  \
# 455         489    Vanaparty       NaN  10/23/2015 0:00  8/25/2018 21:59
#
#      District      State               Category Connection Type        Lat  \
# 455  Warangal  Telangana  District Headquarters        Domestic  17.956816
#
#            Lon         t2m       u10       v10        tp
# 455  79.602123  297.868408  2.616627  0.989978  0.002155

# %%
print(tree)
# Out:
# <scipy.spatial._kdtree.KDTree object at 0x3de33c3c0>

# %%
grid_points.shape
# Out:
# (41888, 2)

# %%
nearest_grid_idx.shape
# Out:
# (538,)

# %%
print(df.head(10))
# Out:
#                            t2m       u10       v10        tp      date  time
# latitude longitude
# 31.032   72.475     300.255127 -1.978100 -1.211438  0.006685  20130802  2100
#          72.575     300.247314 -2.019360 -1.190198  0.006008  20130802  2100
#          72.675     300.222900 -2.108715 -1.147107  0.005398  20130802  2100
#          72.775     300.167236 -2.232494 -1.089002  0.004810  20130802  2100
#          72.875     300.144775 -2.368969 -1.029065  0.004218  20130802  2100
#          72.975     300.111572 -2.486401 -0.975110  0.003846  20130802  2100
#          73.075     299.937744 -2.575024 -0.948255  0.003750  20130802  2100
#          73.175     299.839111 -2.652905 -0.917249  0.003808  20130802  2100
#          73.275     299.814697 -2.727612 -0.905530  0.004418  20130802  2100
#          73.375     299.803955 -2.799145 -0.903333  0.006137  20130802  2100

# %%
input_dir = f'{year}'
station_file='STATION.csv'
station_df = pd.read_csv(station_file)
output_dir = f'station_by_datetime_csv/{year}'

for file in os.listdir(input_dir):
    
    if  file.endswith('.grib'):
        print(file)

		grbs = read_grib_file(os.path.join(input_dir, file))
		
		with xr.open_dataset(os.path.join(input_dir, file)) as ds:
			df = ds.to_dataframe()
		
			df = df.drop(columns=['number', 'time', 'step', 'surface', 'valid_time'])
			# get date and time
			date = file.split('_')[2]
			time = file.split('_')[3].split('.')[0]
			# add date and time to df
			
			df['date'] = date
			df['time'] = time

			print(df.head(10))

			
			# build KDTree
			tree, grid_points = build_kdtree(df)
			# find nearest grid points
			nearest_grid_idx = find_nearest_grid_points(tree, station_df)
			# assign nearest grid values

			station_df = assign_nearest_grid_values(df, station_df, grid_points, nearest_grid_idx)

			# save to csv
			station_df.to_csv(f'{output_dir}/{date}_{time}_station.csv')

			print(f'{output_dir}/{date}_{time}_station.csv')

			print('done')
# Out:
#   File <tokenize>:43
#     break
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
file
# Out:
# 'era5_land_20130802_2100.grib'

# %%
xr.open_dataset(file)

# %%
			tree, grid_points = build_kdtree(df)
			# find nearest grid points
			nearest_grid_idx = find_nearest_grid_points(tree, station_df)
			# assign nearest grid values

			station_df = assign_nearest_grid_values(df, station_df, grid_points, nearest_grid_idx)

			# save to csv
			station_df.to_csv(f'{output_dir}/{date}_{time}_station.csv')

			print(f'{output_dir}/{date}_{time}_station.csv')

			print('done')

# %%
import os
import pandas as pd

# Define the input and output directories
input_base_dir = '../../data/GRIB'
output_base_dir = '../../data/csv'

# Function to process each file
def process_grib_file(grib_file, station_df, df):
    """
    Process a single GRIB file: find nearest grid points and save station data to CSV.
    
    Args:
        grib_file (str): The path to the GRIB file.
        station_df (pd.DataFrame): The station data DataFrame.
        df (pd.DataFrame): The grid data DataFrame extracted from the GRIB file.
    
    Returns:
        pd.DataFrame: Station data with grid attributes for the given file.
    """
    # Here you should load the GRIB data into `df`
    # Placeholder for GRIB loading logic
    # df = load_grib_file(grib_file)  # You need to implement this function
    
    # Build the KDTree and process the stations
    tree, grid_points = build_kdtree(df)
    nearest_grid_idx = find_nearest_grid_points(tree, station_df)
    station_df_with_grid_data = assign_nearest_grid_values(df, station_df, grid_points, nearest_grid_idx)
    
    return station_df_with_grid_data

# Loop through each year folder
for year in range(2022, 2022):
    input_year_dir = os.path.join(input_base_dir, str(year))
    output_year_dir = os.path.join(output_base_dir, str(year))
    
    # Create the output directory if it doesn't exist
    os.makedirs(output_year_dir, exist_ok=True)
    
    # Loop through all GRIB files in the current year folder
    for grib_file in os.listdir(input_year_dir):
        if grib_file.endswith('.grib'):
            # Extract the timestamp (YYYYMMDD_HHMM) from the filename
            timestamp = grib_file.replace('era5_land_', '').replace('.grib', '')
            
            # Construct the output CSV file path
            output_csv_file = os.path.join(output_year_dir, f"era5_land_{timestamp}.csv")
            
            # Full path to the current GRIB file
            grib_file_path = os.path.join(input_year_dir, grib_file)
            
            # Placeholder for station_df (you need to load station data before the loop)
            station_df = load_station_data()  # Assuming you have station data loaded here
            
            # Placeholder for grib_df (grid data loaded from GRIB file)
            grib_df = load_grib_data(grib_file_path)  # You need to implement this function
            
            # Process the GRIB file and get the output
            station_df_with_grid_data = process_grib_file(grib_file_path, station_df, grib_df)
            
            # Save the resulting DataFrame to CSV
            station_df_with_grid_data.to_csv(output_csv_file, index=False)

            print(f"Processed and saved: {output_csv_file}")

# %%
# Step 1: Extract the grid coordinates from the grib data
grid_points = np.array(list(zip(df.index.get_level_values('latitude'), df.index.get_level_values('longitude'))))

# Step 2: Build the KDTree
tree = KDTree(grid_points)

# Step 3: For each station coordinate, find the nearest grid point
station_coords = station_df[['Lat', 'Lon']].to_numpy()

# Query the nearest point in the KDTree
_, nearest_grid_idx = tree.query(station_coords)

# Step 4: Use the index to get the corresponding grid data
nearest_grid_points = grid_points[nearest_grid_idx]
print(nearest_grid_points)
print(type(nearest_grid_points))

df.index = pd.MultiIndex.from_tuples(
    [(round(lat, 3), round(lon, 3)) for lat, lon in df.index], 
)

df.index

# Step 5: Convert nearest_grid_points to tuples (lat, lon)
nearest_grid_points = [(round(lat, 3), round(lon, 3)) for lat, lon in nearest_grid_points]

# Step 6: Make sure the index of the df is also rounded and in the same format
df.index = pd.MultiIndex.from_tuples(
    [(round(lat, 3), round(lon, 3)) for lat, lon in df.index], 
    names=['lat', 'lon']
)

# Step 7: Use the nearest grid points to get corresponding values from df
# Ensure nearest_grid_points is a list of tuples
nearest_grid_values = df.loc[nearest_grid_points].reset_index()

# Now you can join this with the station_df
station_df = pd.concat([station_df.reset_index(drop=True), nearest_grid_values[['t2m', 'u10', 'v10','tp','date','time']]], axis=1)

station_df.to_csv(f'{output_dir}/{date}_{time}_station.csv')

print(f'{output_dir}/{date}_{time}_station.csv')

print('done')
