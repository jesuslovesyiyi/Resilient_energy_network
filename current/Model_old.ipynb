# %%
# -----********************-----

# Created Time: 2024/12/09

# Last updated: 2024/12/11

# Author: Yiyi He, Tara Liu

### Use Case

# This notebook explores the application of autoregressive models
# 1. 

# -----********************-----

# %% [markdown]
# # Libraries

# %%
# Import libraries
import os
import warnings
from pathlib import Path
warnings.filterwarnings("ignore")

# Stats
from statsmodels.tsa.api import ARDL
import statsmodels.api as sm
import numpy as np
from statsmodels.tsa.ardl import ardl_select_order
from statsmodels.tsa.stattools import grangercausalitytests

# Geo
from shapely.geometry import Point, Polygon
# import geopandas as gpd
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.options.display.max_rows = 1000

# Plot
import matplotlib.pyplot as plt
import seaborn as sns

# Processing
from tqdm import tqdm
import functools as ft

# %%
# Define functions
def find_lag(df, maxlag):

    time_start = pd.Timestamp.now()
    
    sel_res = ardl_select_order(
        df['pct_blackout'],
        exog=df[['t2m', 'wind_speed', 'tp']],
        maxlag=maxlag,
        ic='aic',
        maxorder=maxlag,
        causal=True,
        trend='ct'
        )
    
    time_selected = pd.Timestamp.now()
    print(f'time elapsed for selecting order: {time_selected-time_start}')
    
    return sel_res.model.ardl_order

# %% [markdown]
# # ARDL find lag

# %% [markdown]
# ## Hourly

# %%
# Load input dataframe
df_518 = pd.read_csv("/Users/yiyi/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology(2)/Research/Energy_resilience/01_data/processed/station_518_forest_perc_50kmBu_district_climate_dummy_df.csv",
                     index_col=0)
df_518.head(3)
# Out:
#               datetime  pct_blackout  wind_forest_cover        t2m  \
# 0  2014-11-17 17:00:00           0.0                0.0  295.09723
# 1  2014-11-29 17:00:00           0.0                0.0  293.04870
# 2  2014-11-30 22:00:00           0.0                0.0  289.83447
#
#              tp  wind_speed  station_id climate_zone_code  \
# 0  5.645638e-04    1.310930         495                Aw
# 1  0.000000e+00    2.215274         495                Aw
# 2  4.351137e-07    2.000125         495                Aw
#
#    forest_perc_50kmbuffer  forest_perc_district  wind_forest_cover_50kmbu  \
# 0                  0.0006                0.0006                  0.000787
# 1                  0.0006                0.0006                  0.001329
# 2                  0.0006                0.0006                  0.001200
#
#    wind_forest_cover_district  Am  Aw  BSh  Cw
# 0                    0.000787   0   1    0   0
# 1                    0.001329   0   1    0   0
# 2                    0.001200   0   1    0   0

# %%
df_518.datetime.min()
# Out:
# '2014-10-22 00:00:00'

# %%
df_518.datetime.max()
# Out:
# '2023-12-26 12:00:00'

# %%
# Create a list of unique station ids
station_id_lst = list(set(df_518.station_id.unique()))
# Initiate an empty dictionary
station_id_lag_dic = {}
# Set max lag
maxlag = 24
# Iterate through all stations
for s_id in tqdm(station_id_lst):
    # Subset station data
    station_df = df_518[df_518['station_id'] == s_id].sort_values(by='datetime')
    # Find optimum lag and store station id with optimum lag in dictionary
    sel_res = ardl_select_order(
        station_df['pct_blackout'],
        exog=station_df[['t2m', 'wind_speed', 'tp']],
        maxlag=maxlag,
        ic='bic',
        maxorder=maxlag,
        causal=True,
        trend='ct'
        )
    # optimum lag values for endogenous variables
    endo_res_lst = list(sel_res.aic.values[0][1].values())
    # insert the optimum lag value for exdogenous variable
    endo_res_lst.insert(0, sel_res.aic.values[0][0])
    # store station id and optimum lag values in dictionary
    station_id_lag_dic[s_id] = endo_res_lst # key: station id, value:[pct_blackout_lag, t2m_lag, wind_speed_lag, tp_lag]

station_id_lag_dic_copy = station_id_lag_dic
station_id_lag_df = pd.DataFrame.from_dict(station_id_lag_dic_copy, orient='index')

station_id_optimum_lag_bic_df = station_id_lag_df.reset_index().rename(columns={
                                                          'index': 'station_id',
                                                          0: 'pct_blackout_lag',
                                                          1: 't2m_lag',
                                                          2: 'wind_speed_lag',
                                                          3: 'tp_lag'
                                                          })
station_id_optimum_lag_bic_df.to_csv('/Users/yiyi/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_516_ARDL_optimum_lag_bic_max24_df.csv')

# %% [markdown]
# ## Daily

# %% [markdown]
# ### 8 variables

# %% [markdown]
# #### Correlation

# %%
# Read in dataframe
station_daily_agg = pd.read_csv('/Users/yiyi/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology(2)/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_518_weather_daily_agg.csv',
                                index_col=0)
correlation_matrix = station_daily_agg[['blackout_minutes',
                                        't2m_min',
                                        't2m_median',
                                        't2m_max',
                                        'wind_speed_median',
                                        'wind_speed_max',
                                        'tp_median',
                                        'tp_max']].corr()
correlation_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_7632f_row0_col0, #T_7632f_row1_col1, #T_7632f_row2_col2, #T_7632f_row3_col3, #T_7632f_row4_col4, #T_7632f_row5_col5, #T_7632f_row6_col6, #T_7632f_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7632f_row0_col1, #T_7632f_row0_col4, #T_7632f_row0_col5, #T_7632f_row3_col6, #T_7632f_row3_col7, #T_7632f_row4_col0, #T_7632f_row6_col2, #T_7632f_row6_col3, #T_7632f_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7632f_row0_col2, #T_7632f_row7_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_7632f_row0_col3, #T_7632f_row2_col7 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_7632f_row0_col6, #T_7632f_row6_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_7632f_row0_col7 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_7632f_row1_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_7632f_row1_col2, #T_7632f_row2_col1 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_7632f_row1_col3 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_7632f_row1_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_7632f_row1_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_7632f_row1_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_7632f_row1_col7 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_7632f_row2_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_7632f_row2_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_7632f_row2_col4 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_7632f_row2_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_7632f_row2_col6 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_7632f_row3_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_7632f_row3_col1 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_7632f_row3_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_7632f_row3_col4 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_7632f_row3_col5, #T_7632f_row4_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_7632f_row4_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_7632f_row4_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_7632f_row4_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_7632f_row4_col5 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_7632f_row4_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_7632f_row5_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_7632f_row5_col1, #T_7632f_row5_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_7632f_row5_col2 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_7632f_row5_col4 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_7632f_row5_col6, #T_7632f_row7_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_7632f_row5_col7 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_7632f_row6_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_7632f_row6_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_7632f_row6_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_7632f_row6_col7 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_7632f_row7_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_7632f_row7_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_7632f_row7_col5 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_7632f_row7_col6 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7632f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7632f_level0_col0" class="col_heading level0 col0" >blackout_minutes</th>
#       <th id="T_7632f_level0_col1" class="col_heading level0 col1" >t2m_min</th>
#       <th id="T_7632f_level0_col2" class="col_heading level0 col2" >t2m_median</th>
#       <th id="T_7632f_level0_col3" class="col_heading level0 col3" >t2m_max</th>
#       <th id="T_7632f_level0_col4" class="col_heading level0 col4" >wind_speed_median</th>
#       <th id="T_7632f_level0_col5" class="col_heading level0 col5" >wind_speed_max</th>
#       <th id="T_7632f_level0_col6" class="col_heading level0 col6" >tp_median</th>
#       <th id="T_7632f_level0_col7" class="col_heading level0 col7" >tp_max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7632f_level0_row0" class="row_heading level0 row0" >blackout_minutes</th>
#       <td id="T_7632f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7632f_row0_col1" class="data row0 col1" >0.019081</td>
#       <td id="T_7632f_row0_col2" class="data row0 col2" >0.025478</td>
#       <td id="T_7632f_row0_col3" class="data row0 col3" >0.022975</td>
#       <td id="T_7632f_row0_col4" class="data row0 col4" >-0.003872</td>
#       <td id="T_7632f_row0_col5" class="data row0 col5" >0.003098</td>
#       <td id="T_7632f_row0_col6" class="data row0 col6" >0.034876</td>
#       <td id="T_7632f_row0_col7" class="data row0 col7" >0.040627</td>
#     </tr>
#     <tr>
#       <th id="T_7632f_level0_row1" class="row_heading level0 row1" >t2m_min</th>
#       <td id="T_7632f_row1_col0" class="data row1 col0" >0.019081</td>
#       <td id="T_7632f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7632f_row1_col2" class="data row1 col2" >0.909367</td>
#       <td id="T_7632f_row1_col3" class="data row1 col3" >0.719370</td>
#       <td id="T_7632f_row1_col4" class="data row1 col4" >0.261768</td>
#       <td id="T_7632f_row1_col5" class="data row1 col5" >0.353571</td>
#       <td id="T_7632f_row1_col6" class="data row1 col6" >0.194946</td>
#       <td id="T_7632f_row1_col7" class="data row1 col7" >0.220751</td>
#     </tr>
#     <tr>
#       <th id="T_7632f_level0_row2" class="row_heading level0 row2" >t2m_median</th>
#       <td id="T_7632f_row2_col0" class="data row2 col0" >0.025478</td>
#       <td id="T_7632f_row2_col1" class="data row2 col1" >0.909367</td>
#       <td id="T_7632f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7632f_row2_col3" class="data row2 col3" >0.919263</td>
#       <td id="T_7632f_row2_col4" class="data row2 col4" >0.181428</td>
#       <td id="T_7632f_row2_col5" class="data row2 col5" >0.295282</td>
#       <td id="T_7632f_row2_col6" class="data row2 col6" >0.007708</td>
#       <td id="T_7632f_row2_col7" class="data row2 col7" >0.024257</td>
#     </tr>
#     <tr>
#       <th id="T_7632f_level0_row3" class="row_heading level0 row3" >t2m_max</th>
#       <td id="T_7632f_row3_col0" class="data row3 col0" >0.022975</td>
#       <td id="T_7632f_row3_col1" class="data row3 col1" >0.719370</td>
#       <td id="T_7632f_row3_col2" class="data row3 col2" >0.919263</td>
#       <td id="T_7632f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_7632f_row3_col4" class="data row3 col4" >0.094203</td>
#       <td id="T_7632f_row3_col5" class="data row3 col5" >0.227821</td>
#       <td id="T_7632f_row3_col6" class="data row3 col6" >-0.172067</td>
#       <td id="T_7632f_row3_col7" class="data row3 col7" >-0.171307</td>
#     </tr>
#     <tr>
#       <th id="T_7632f_level0_row4" class="row_heading level0 row4" >wind_speed_median</th>
#       <td id="T_7632f_row4_col0" class="data row4 col0" >-0.003872</td>
#       <td id="T_7632f_row4_col1" class="data row4 col1" >0.261768</td>
#       <td id="T_7632f_row4_col2" class="data row4 col2" >0.181428</td>
#       <td id="T_7632f_row4_col3" class="data row4 col3" >0.094203</td>
#       <td id="T_7632f_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_7632f_row4_col5" class="data row4 col5" >0.871425</td>
#       <td id="T_7632f_row4_col6" class="data row4 col6" >0.092445</td>
#       <td id="T_7632f_row4_col7" class="data row4 col7" >0.105082</td>
#     </tr>
#     <tr>
#       <th id="T_7632f_level0_row5" class="row_heading level0 row5" >wind_speed_max</th>
#       <td id="T_7632f_row5_col0" class="data row5 col0" >0.003098</td>
#       <td id="T_7632f_row5_col1" class="data row5 col1" >0.353571</td>
#       <td id="T_7632f_row5_col2" class="data row5 col2" >0.295282</td>
#       <td id="T_7632f_row5_col3" class="data row5 col3" >0.227821</td>
#       <td id="T_7632f_row5_col4" class="data ro

# %%
correlation_matrix = station_daily_agg[['blackout_minutes',
                                        't2m_max',
                                        'wind_speed_max',
                                        'tp_max']].corr()
correlation_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_0adb4_row0_col0, #T_0adb4_row1_col1, #T_0adb4_row2_col2, #T_0adb4_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0adb4_row0_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_0adb4_row0_col2, #T_0adb4_row1_col3, #T_0adb4_row2_col0, #T_0adb4_row3_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0adb4_row0_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_0adb4_row1_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_0adb4_row1_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_0adb4_row2_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_0adb4_row2_col3 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_0adb4_row3_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_0adb4_row3_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0adb4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0adb4_level0_col0" class="col_heading level0 col0" >blackout_minutes</th>
#       <th id="T_0adb4_level0_col1" class="col_heading level0 col1" >t2m_max</th>
#       <th id="T_0adb4_level0_col2" class="col_heading level0 col2" >wind_speed_max</th>
#       <th id="T_0adb4_level0_col3" class="col_heading level0 col3" >tp_max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0adb4_level0_row0" class="row_heading level0 row0" >blackout_minutes</th>
#       <td id="T_0adb4_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0adb4_row0_col1" class="data row0 col1" >0.022975</td>
#       <td id="T_0adb4_row0_col2" class="data row0 col2" >0.003098</td>
#       <td id="T_0adb4_row0_col3" class="data row0 col3" >0.040627</td>
#     </tr>
#     <tr>
#       <th id="T_0adb4_level0_row1" class="row_heading level0 row1" >t2m_max</th>
#       <td id="T_0adb4_row1_col0" class="data row1 col0" >0.022975</td>
#       <td id="T_0adb4_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0adb4_row1_col2" class="data row1 col2" >0.227821</td>
#       <td id="T_0adb4_row1_col3" class="data row1 col3" >-0.171307</td>
#     </tr>
#     <tr>
#       <th id="T_0adb4_level0_row2" class="row_heading level0 row2" >wind_speed_max</th>
#       <td id="T_0adb4_row2_col0" class="data row2 col0" >0.003098</td>
#       <td id="T_0adb4_row2_col1" class="data row2 col1" >0.227821</td>
#       <td id="T_0adb4_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0adb4_row2_col3" class="data row2 col3" >0.088638</td>
#     </tr>
#     <tr>
#       <th id="T_0adb4_level0_row3" class="row_heading level0 row3" >tp_max</th>
#       <td id="T_0adb4_row3_col0" class="data row3 col0" >0.040627</td>
#       <td id="T_0adb4_row3_col1" class="data row3 col1" >-0.171307</td>
#       <td id="T_0adb4_row3_col2" class="data row3 col2" >0.088638</td>
#       <td id="T_0adb4_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### ARDL

# %%
# Read in dataframe
station_daily_agg = pd.read_csv('/Users/yiyi/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology(2)/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_518_weather_daily_agg.csv',
                                index_col=0)
station_daily_agg.head(3)

# Set max lag
maxlag = 5
# Target
target = "blackout_minutes"
predictors_lst = [
                't2m_min',
                't2m_median',
                't2m_max',
                'wind_speed_median',
                'wind_speed_max',
                'tp_median',
                'tp_max']

# Create a list of unique station ids
station_id_lst = list(set(station_daily_agg.station_id.unique()))

# Identify stations with fewer than 90 days worth of data
groupby_station = station_daily_agg.groupby('station_id')
fewer90_station_ids = groupby_station.count()[groupby_station.count().date<92].index.values # np array

# Initiate an empty dictionary
station_id_daily_lag_bic = {}

# Iterate through all stations
for s_id in tqdm(station_id_lst):
    if s_id in fewer90_station_ids:
        continue
    else:
        # Subset station data
        station_df = station_daily_agg[station_daily_agg['station_id'] == s_id].sort_values(by='date')
        # Find optimum lag and store station id with optimum lag in dictionary
        sel_res = ardl_select_order(
            station_df[target],
            exog=station_df[predictors_lst],
            maxlag=maxlag,
            ic='bic',
            maxorder=maxlag,
            causal=True,
            trend='ct'
            )
        # optimum lag values for endogenous variables
        endo_res_lst = list(sel_res.bic.values[0][1].values())
        # insert the optimum lag value for exdogenous variable
        endo_res_lst.insert(0, sel_res.bic.values[0][0])
        # store station id and optimum lag values in dictionary
        station_id_daily_lag_bic[s_id] = endo_res_lst # key: station id, value:[pct_blackout_lag, t2m_lag, wind_speed_lag, tp_lag]

station_id_daily_lag_bic_df = pd.DataFrame.from_dict(station_id_lag_dic_copy, orient='index')

station_id_optimum_lag_bic_df = station_id_lag_df.reset_index().rename(columns={
                                                                       'index': 'station_id',
                                                                    0: 'blackout_m_lag',
                                                                    1: 't2m_min_lag',
                                                                    2: 't2m_median_lag',
                                                                    3: 't2m_max_lag',
                                                                    4: 'wind_speed_median_lag',
                                                                    5: 'wind_speed_max_lag',
                                                                    6: 'tp_median_lag',
                                                                    7: 'tp_max_lag'
                                                                    })
station_id_optimum_lag_bic_df.to_csv('/Users/yiyi/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology(2)/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_id_daily_lag5_bic_df.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 30
#      27 station_id_daily_lag_bic = {}
#      29 # Iterate through all stations
# ---> 30 for s_id in tqdm(station_id_lst):
#      31     if s_id in fewer90_station_ids:
#      32         continue
#
# NameError: name 'tqdm' is not defined

# %% [markdown]
# ### 3 variables

# %%
# Read in dataframe
mac_yh_path = "/Users/yiyihe/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_518_weather_daily_agg.csv"
station_daily_agg = pd.read_csv(mac_yh_path,
                                index_col=0)
station_daily_agg.head(3)

# Set max lag
maxlag = 7
# Target
target = "blackout_minutes"
predictors_lst = [
                # 't2m_min',
                # 't2m_median',
                't2m_max',
                # 'wind_speed_median',
                'wind_speed_max',
                # 'tp_median',
                'tp_max']

# Create a list of unique station ids
station_id_lst = list(set(station_daily_agg.station_id.unique()))

# Identify stations with fewer than 90 days worth of data
groupby_station = station_daily_agg.groupby('station_id')
fewer90_station_ids = groupby_station.count()[groupby_station.count().date<92].index.values # np array

# Initiate an empty dictionary
station_id_daily_lag_bic = {}

# Iterate through all stations
for s_id in tqdm(station_id_lst):
    if s_id in fewer90_station_ids:
        continue
    else:
        # Subset station data
        station_df = station_daily_agg[station_daily_agg['station_id'] == s_id].sort_values(by='date')
        # Find optimum lag and store station id with optimum lag in dictionary
        sel_res = ardl_select_order(
            station_df[target],
            exog=station_df[predictors_lst],
            maxlag=maxlag,
            ic='bic',
            maxorder=maxlag,
            causal=True,
            trend='ct'
            )
        # optimum lag values for endogenous variables
        endo_res_lst = list(sel_res.bic.values[0][1].values())
        # insert the optimum lag value for exdogenous variable
        endo_res_lst.insert(0, sel_res.bic.values[0][0])
        # store station id and optimum lag values in dictionary
        station_id_daily_lag_bic[s_id] = endo_res_lst # key: station id, value:[pct_blackout_lag, t2m_lag, wind_speed_lag, tp_lag]
# Out:
#   0%|          | 0/516 [00:00<?, ?it/s]

# %%
station_id_daily_lag_bic_df = pd.DataFrame.from_dict(station_id_daily_lag_bic, orient='index')

station_id_optimum_lag_bic_df = station_id_daily_lag_bic_df.reset_index().rename(columns={
                                                                    'index': 'station_id',
                                                                    0: 'blackout_m_lag',
                                                                    1: 't2m_max_lag',
                                                                    2: 'wind_speed_max_lag',
                                                                    3: 'tp_max_lag'
                                                                    })
station_id_optimum_lag_bic_df.to_csv('/Users/yiyi/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology(2)/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_id_daily_lag14_max_weather_bic_df.csv')

# %% [markdown]
# #### Coefficients

# %% [markdown]
# Create dataframes of coefficients for each station. P-values are also added as an additional dataframe

# %%
# Read in dataframe
mac_yh_path = "/Users/yiyihe/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_518_weather_daily_agg.csv"
station_daily_agg = pd.read_csv(mac_yh_path,
                                index_col=0)

# Initiate an empty dictionary
station_id_daily_lag7_bic = {}

# Set max lag
maxlag = 7
# Target
target = "blackout_minutes"
predictors_lst = [
                # 't2m_min',
                # 't2m_median',
                't2m_max',
                # 'wind_speed_median',
                'wind_speed_max',
                # 'tp_median',
                'tp_max']

# Create a list of unique station ids
station_id_lst = list(set(station_daily_agg.station_id.unique()))

# Identify stations with fewer than 90 days worth of data
groupby_station = station_daily_agg.groupby('station_id')
fewer90_station_ids = groupby_station.count()[groupby_station.count().date<92].index.values # np array

# Initiate an empty dictionary
station_id_daily_maxlag7_bic_coefficients = {}
station_id_daily_maxlag7_bic_pvalues = {}

# Iterate through all stations
for s_id in tqdm(station_id_lst):
    if s_id in fewer90_station_ids:
        continue
    else:
        # Subset station data
        station_df = station_daily_agg[station_daily_agg['station_id'] == s_id].sort_values(by='date')
        # Find optimum lag and store station id with optimum lag in dictionary
        sel_res = ardl_select_order(
            station_df[target],
            exog=station_df[predictors_lst],
            maxlag=maxlag,
            ic='bic',
            maxorder=maxlag,
            causal=True,
            trend='ct'
            )
        model = sel_res.model.fit()
        # np array of index + coefficients
        station_id_daily_maxlag7_bic_coefficients[s_id] = np.append(model.params.index.values, model.params.values)
        station_id_daily_maxlag7_bic_pvalues[s_id] = np.append(model.pvalues.index.values, model.pvalues.values)
# Out:
# 100%|██████████| 516/516 [09:12<00:00,  1.07s/it]

# %% [markdown]
# Process the raw dataframe of coefficients.

# %%
# Max lag = 7
target = "blackout_minutes"
predictors_lst = ['t2m_max', 'wind_speed_max', 'tp_max']

mac_studio_path = "/Users/yiyi/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology(2)/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_id_daily_maxlag7_bic_coefficients_raw.csv"
mac_pro_path = "/Users/yiyihe/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_id_daily_maxlag7_bic_coefficients_raw.csv"
coeff_raw = pd.read_csv(mac_pro_path, index_col=0)

columns_names = ['const', 'trend'] + [predictor + ".L" + str(i) for predictor in [target] + predictors_lst for i in range(1, 8)]

# Initiate a new dataframe with processed coefficients
coeff_processed = pd.DataFrame(index=coeff_raw.index, columns=columns_names)

# Populate dataframe with coefficients
for row in range(coeff_raw.shape[0]):
    # row values
    row_arr = coeff_raw.iloc[row].dropna().values
    # mid index (as the row values consists of a string protion followed by coefficients, they are the same length)
    mid_index = row_arr.shape[0] // 2

    # string portion
    row_str = row_arr[ :mid_index]
    # cofficient portion
    row_coeff = row_arr[mid_index: ]

    # Populate dataframe
    for idx, item in enumerate(row_str):
        coeff_processed.loc[coeff_raw.index[row], item] = row_coeff[idx]

coeff_processed.to_csv("/Users/yiyihe/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_id_daily_maxlag7_bic_coefficients_final.csv")

# %% [markdown]
# #### Output

# %%
# Frequency of variables that contribute to the ARDL model
station_id_optimum_lag_bic_df = pd.read_csv('/Users/yiyi/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology(2)/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_id_daily_lag14_max_weather_bic_df.csv',
                                            index_col=0)
station_id_optimum_lag_bic_df[["blackout_m_lag", "t2m_max_lag", "wind_speed_max_lag", "tp_max_lag"]].notna().astype(int).sum()
# Out:
# blackout_m_lag        397
# t2m_max_lag            85
# wind_speed_max_lag     30
# tp_max_lag            105
# dtype: int64

# %%
# Number of variables contributing to the final ARDL model
station_id_optimum_lag_bic_df[["blackout_m_lag", "t2m_max_lag", "wind_speed_max_lag", "tp_max_lag"]].notna().astype(int).sum(axis=1).value_counts()
# Out:
# 1    278
# 2    118
# 0     39
# 3     33
# 4      1
# Name: count, dtype: int64

# %%
station_id_optimum_lag_bic_df.describe()
# Out:
#        station_id  blackout_m_lag  t2m_max_lag  wind_speed_max_lag  tp_max_lag
# count  469.000000      397.000000    85.000000           30.000000  105.000000
# mean   284.211087        1.773300     1.305882            1.100000    2.038095
# std    166.479190        1.832367     1.123595            0.305129    2.222801
# min      1.000000        1.000000     1.000000            1.000000    1.000000
# 25%    141.000000        1.000000     1.000000            1.000000    1.000000
# 50%    279.000000        1.000000     1.000000            1.000000    1.000000
# 75%    430.000000        2.000000     1.000000            1.000000    2.000000
# max    571.000000       14.000000    10.000000            2.000000   14.000000

# %% [markdown]
# # Granger Causality

# %% [markdown]
# ## Hourly

# %%
# Create a list of unique station ids
station_id_lst = list(set(df_518.station_id.unique()))
# Set max lag
maxlag = 72
# Target
target = "pct_blackout"
# Predictor
predictor = "tp"

# Initiate an empty dictionary
station_id_tp_gc_max72_dic = {}

# List of stations visited
# existing_keys = station_id_t2m_gc_max72_dic.keys()
# Iterate through all stations
for s_id in tqdm(station_id_lst):
    if s_id == 518 or s_id == 563:
        continue 
    else:
        # Subset station data
        station_df = df_518[df_518['station_id'] == s_id].sort_values(by='datetime')
        test_result = grangercausalitytests(
            station_df[[target, predictor]], maxlag=maxlag, addconst=True, verbose=False)
        F_test_p_values = [round(test_result[i+1][0]['ssr_ftest'][1],4) for i in range(maxlag)]
        Chi_squared_p_values = [round(test_result[i+1][0]['ssr_chi2test'][1],4) for i in range(maxlag)]
        p_values_min = np.min(F_test_p_values+Chi_squared_p_values)
        # Key: station id, Value: list of 1. minimum F/Chi p values 2. F-test p values for all lags 3. Chi-square test p-values for all lags
        station_id_tp_gc_max72_dic[s_id] = [p_values_min, F_test_p_values, Chi_squared_p_values]
# Out:
# 100%|██████████| 516/516 [2:03:30<00:00, 14.36s/it]

# %%
# Store granger causality results (p values for 2 tests, minimum p-value) for one predictor in dataframe
station_id_tp_gc_max72_df = pd.DataFrame.from_dict(station_id_tp_gc_max72_dic, orient='index').reset_index()
station_id_tp_gc_max72_df.rename(columns={
    'index':'station_id',
    0:'tp_p-value_min',
    1:'tp_f_p-value',
    2:'tp_Chi_p-value'
}, inplace=True)
# Join dataframes
dfs = [station_id_t2m_gc_max72_df, station_id_windspeed_gc_max72_df, station_id_tp_gc_max72_df]
df_joined= ft.reduce(lambda left, right: pd.merge(left, right, on='station_id'), dfs)
# df_joined.to_csv('/Users/yiyi/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_514_gc_max72_pvalue_df.csv')

# %% [markdown]
# Summary of the results of granger causality

# %%
df_pvalues_max72 = df_joined[['station_id', 't2m_p-value_min', 'windspeed_p-value_min', 'tp_p-value_min']]
station_daily_gc_max30_df_pmin_binarydf_pvalues_max72_binary = df_pvalues_max72.set_index('station_id')<0.05
summary = pd.DataFrame({
    'True': df_pvalues_max72_binary.apply(lambda x: (x == True).sum()),
    'False': df_pvalues_max72_binary.apply(lambda x: (x == False).sum())
    })
summary
# df_pvalues_max72.to_csv('/Users/yiyi/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_514_gc_max72_pvalue_reduced.csv')

# %% [markdown]
# ## Daily

# %%
# Read in dataframe
station_daily_agg = pd.read_csv('/Users/yiyi/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/Research/Energy_resilience/01_data/2024_9_10_Tingyu/processed/station_518_weather_daily_agg.csv',
                                index_col=0)
station_daily_agg.head(3)

# Output folder path
out_folder = Path.home()\
/"Library/CloudStorage/"\
/"OneDrive-GeorgiaInstituteofTechnology/"\
/"Research/Energy_resilience/01_data/"\
/"2024_9_10_Tingyu/processed/daily_maxlag30_dfs/"

# Identify stations with fewer than 90 days worth of data
groupby_station = station_daily_agg.groupby('station_id')
fewer90_station_ids = groupby_station.count()[groupby_station.count().date<92].index.values

# Create a list of unique station ids
station_id_lst = list(set(station_daily_agg.station_id.unique()))

# Set max lag
maxlag = 30
# Target
target = "blackout_minutes"
# Predictors
weather_variables = ['t2m', 'wind_speed', 'tp']
aggregations = ['min', 'median', 'mean', 'max']
predictor_lst = [w + "_" + a for w in weather_variables for a in aggregations]

for predictor in predictor_lst:
    # Initiate an empty dictionary
    station_dic = {}

    for s_id in tqdm(station_id_lst):
        if s_id in fewer90_station_ids:
            continue 
        else:
            # Subset station data
            station_df = station_daily_agg[station_daily_agg['station_id'] == s_id].sort_values(by='date')
            try:
                test_result = grangercausalitytests(
                    station_df[[target, predictor]], maxlag=maxlag, addconst=True, verbose=False)
                F_test_p_values = [round(test_result[i+1][0]['ssr_ftest'][1],4) for i in range(maxlag)]
                Chi_squared_p_values = [round(test_result[i+1][0]['ssr_chi2test'][1],4) for i in range(maxlag)]
                p_values_min = np.min(F_test_p_values+Chi_squared_p_values)
                # Key: station id, Value: list of 1. minimum F/Chi p values 2. F-test p values for all lags 3. Chi-square test p-values for all lags
                station_dic[s_id] = [p_values_min, F_test_p_values, Chi_squared_p_values]
            except:
                station_dic[s_id] = [np.nan, np.nan, np.nan]

    station_gc_max30_df = pd.DataFrame.from_dict(station_dic, orient='index').reset_index()
    station_gc_max30_df.rename(columns={
    'index':'station_id',
    0:f'{predictor}_p-value_min',
    1:f'{predictor}_f_p-value',
    2:f'{predictor}_Chi_p-value'
    }, inplace=True)
    station_gc_max30_df.to_csv(Path(out_folder)/f'station_gc_max30_{predictor}.csv')
# Out:
#  16%|█▋        | 84/516 [00:19<01:34,  4.59it/s]

# %%
out_folder = Path.home()\
/"Library/CloudStorage/"\
/"OneDrive-GeorgiaInstituteofTechnology/"\
/"Research/Energy_resilience/01_data/"\
/"2024_9_10_Tingyu/processed/daily_maxlag30_dfs/"

weather_variables = ['t2m', 'wind_speed', 'tp']
aggregations = ['min', 'median', 'mean', 'max']
pmin_col_names = [w + "_" + a + "_p-value_min"\
                  for w in weather_variables\
                  for a in aggregations]

station_daily_gc_max30_df_lst = []
for file in os.listdir(out_folder):
    if file[-3:] == 'csv':
        df = pd.read_csv(os.path.join(out_folder,file),
                         index_col=0)
        station_daily_gc_max30_df_lst.append(df)
station_daily_gc_max30_df_joined= ft.reduce(lambda left, right: pd.merge(left, right, on='station_id'),
                     station_daily_gc_max30_df_lst)

station_daily_gc_max30_df_pmin = station_daily_gc_max30_df_joined[['station_id']+pmin_col_names]
station_daily_gc_max30_df_pmin_binary = station_daily_gc_max30_df_pmin.set_index('station_id')<0.05
summary = pd.DataFrame({
    'True': station_daily_gc_max30_df_pmin_binary.apply(lambda x: (x == True).sum()),
    'False': station_daily_gc_max30_df_pmin_binary.apply(lambda x: (x == False).sum())
    })
summary.to_csv(Path(out_folder)/'station_daily_gc_max30_p_value_summary.csv')

# %% [markdown]
# ## Other

# %%
# https://www.machinelearningplus.com/time-series/granger-causality-test-in-python/
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

# %%
grangers_causation_matrix(station_df, ['pct_blackout', 't2m', 'wind_speed'])
# Out:
#                 pct_blackout_x   t2m_x  wind_speed_x
# pct_blackout_y          1.0000  0.0271        0.2261
# t2m_y                   0.0472  1.0000        0.0000
# wind_speed_y            0.0023  0.0000        1.0000
